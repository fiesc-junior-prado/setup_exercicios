# %%
import pandas as pd

# Dados dos candidatos finalistas
dados_candidatos = {
    'candidato': ['Alice', 'Bruno', 'Carlos', 'Diana', 'Eduardo', 'Fernanda'],
    'score_logica': [95, 80, 45, 70, 85, 60],
    'anos_experiencia': [2, 5, 15, 1, 8, 20]
}

df_talentos = pd.DataFrame(dados_candidatos)
print("Dataset Original:")
print(df_talentos)
