# %%
import pandas as pd
import numpy as np

# Gerando a base de dados corrompida pelos problemas de rede
dados_sensores = {
    'ID_Sensor': ['S01', 'S02', 'S03', 'S01', None, 'S04', 'S02', 'S05', 'S01'],
    'Timestamp': ['10:00', '10:00', '10:00', '10:00', None, '11:00', '10:00', '11:00', '10:00'],
    'Temperatura_C': [22.5, np.nan, 24.1, 22.5, None, 23.8, np.nan, 21.2, 22.5],
    'Nivel_CO_ppm': [12.0, 15.2, np.nan, 12.0, None, 11.5, 15.2, np.nan, 12.0],
    'Status_Equipamento': ['Operacional', 'Alerta', 'Operacional', 'Operacional', None, 'Operacional', 'Alerta', 'Manutenção', 'Operacional']
}

df_sensores = pd.DataFrame(dados_sensores)
print("=== DATASET BRUTO DOS SENSORES ===")
print(df_sensores)
