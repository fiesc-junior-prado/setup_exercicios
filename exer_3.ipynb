# %%
import pandas as pd

# Dados brutos coletados pelo e-commerce
dados_ecommerce = {
    'id_cliente': [5001, 5002, 5003, 5004, 5005],
    'nivel_fidelidade': ['Prata', 'Bronze', 'Ouro', 'Prata', 'Bronze'],
    'categoria_produto': ['Roupas', 'Calçados', 'Acessórios', 'Roupas', 'Calçados'],
    'usou_cupom': ['Sim', 'Não', 'Não', 'Sim', 'Não']
}

df_marketing = pd.DataFrame(dados_ecommerce)
print("Dados Originais de Marketing:")
print(df_marketing)
