# %%
import pandas as pd

# Simulando a base de dados poluída por duplicatas e atualizações
dados_ingressos = {
    'ID_Ingresso': ['T_001', 'T_002', 'T_001', 'T_003', 'T_002', 'T_004', 'T_004', 'T_005'],
    'Cliente': ['Marcos J.', 'Amanda R.', 'Marcos J.', 'Bruno M.', 'Amanda R.', 'Bot_123', 'Bot_123', 'Carla S.'],
    'Setor': ['Pista Premium', 'Camarote', 'Pista Premium', 'Pista', 'Camarote', 'Pista Premium', 'Pista Premium', 'Camarote'],
    'Preco': [400.00, 800.00, 400.00, 250.00, 800.00, 400.00, 400.00, 800.00],
    'Status_Pagamento': ['Pendente', 'Pendente', 'Aprovado', 'Aprovado', 'Aprovado', 'Recusado', 'Recusado', 'Aprovado']
}

df_ingressos = pd.DataFrame(dados_ingressos)
print("=== RELATÓRIO BRUTO DE VENDAS ===")
print(df_ingressos)
