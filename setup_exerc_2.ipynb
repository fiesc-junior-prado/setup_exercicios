# %%
import pandas as pd
import numpy as np

# Simulando o log corrompido da Fintech
dados_fintech = {
    'ID_Transacao': ['T101', 'T102', 'T103', 'T101', None, 'T104', 'T105', 'T102', 'T106'],
    'ID_Cliente': ['C_99', 'C_88', 'C_77', 'C_99', None, 'C_66', 'C_55', 'C_88', 'C_44'],
    'Metodo_Pagamento': ['Pix', 'Credito', None, 'Pix', None, 'Credito', 'Pix', 'Credito', None],
    'Valor_Transacao': [250.00, 1200.00, 450.00, 250.00, None, np.nan, 80.00, 1200.00, 500.00],
    'Score_Fraude': [0.02, 0.85, 0.12, 0.02, None, 0.99, 0.01, 0.85, np.nan]
}

df_transacoes = pd.DataFrame(dados_fintech)
print("=== LOG DE TRANSAÇÕES BRUTAS ===")
print(df_transacoes)
