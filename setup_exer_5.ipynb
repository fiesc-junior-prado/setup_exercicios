# %%
import pandas as pd
import numpy as np

# Simulando o banco de dados de logística corrompido
dados_logistica = {
    'ID_Conteiner': ['C-01', 'C-02', 'C-03', 'C-01', None, 'C-04', 'C-05', 'C-02', 'C-06'],
    'Rota': ['Xangai-Santos', 'Xangai-Paranaguá', 'Xangai-Santos', 'Xangai-Santos', None, 'Ningbo-Santos', 'Ningbo-Asunção', 'Xangai-Paranaguá', 'Xangai-Santos'],
    'Peso_Toneladas': [24.5, np.nan, 18.2, 24.5, None, 22.0, np.nan, 28.1, 15.0],
    'Status_Seguranca': ['Trancado', 'Alerta', 'Trancado', 'Trancado', None, 'Trancado', 'Trancado', 'Alerta', None],
    'Temperatura_Celsius': [18.5, 21.0, np.nan, 18.5, None, 19.2, 25.0, 21.0, 20.5]
}

df_logistica = pd.DataFrame(dados_logistica)
print("=== LOG DE RASTREAMENTO BRUTO ===")
print(df_logistica)
