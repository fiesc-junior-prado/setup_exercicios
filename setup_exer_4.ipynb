# %%
import pandas as pd
import numpy as np

# Simulando o banco de dados clínico corrompido
dados_clinicos = {
    'ID_Exame': ['E001', 'E002', 'E003', 'E001', None, 'E004', 'E005', 'E002', 'E006'],
    'Paciente': ['Carlos S.', 'Mariana L.', 'Roberto F.', 'Carlos S.', None, 'Juliana M.', 'Pedro A.', 'Mariana L.', 'Fernanda R.'],
    'Idade': [45, np.nan, 52, 45, None, 31, np.nan, 29, 38],
    'Genero': ['M', 'F', 'M', 'M', None, 'F', 'M', 'F', None],
    'Colesterol_Total': [190.0, 210.0, np.nan, 190.0, None, 185.0, 240.0, 210.0, 195.0]
}

df_clinico = pd.DataFrame(dados_clinicos)
print("=== BASE DE DADOS CLÍNICOS BRUTA ===")
print(df_clinico)
